# %%
# start by importing the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Now i will read the data 
path = "C:\\Users\\banji\\Documents\\Excel_Files\\2019NigeriaPresidentialElectio_WebScraped on 09-Aug-2024.xlsx"
data = pd.read_excel(path)

# %%
print(data.columns)
data.head()
# Out:
# Index(['state', ' Muhammadu Buhari APC Votes', ' Atiku Abubakar PDP Votes',
#        ' Felix Nicolas Votes', ' Obadiah Malilafia Votes', 'Other Votes',
#        ' Total Valid Votes', 'Winner of states'],
#       dtype='object')
#        state   Muhammadu Buhari APC Votes   Atiku Abubakar PDP Votes  \
# 0       Abia                        85058                     219698
# 1    Adamawa                       378078                     410266
# 2  Akwa Ibom                       175429                     395832
# 3    Anambra                        33298                     524738
# 4     Bauchi                       798428                     209313
#
#     Felix Nicolas Votes   Obadiah Malilafia Votes  Other Votes  \
# 0                  1489                       336        16710
# 1                  3670                      3989         7231
# 2                  1902                       230         7133
# 3                  4374                       227        37106
# ...

# %%
grouped_data = data.groupby("state").sum().reset_index()
plt.barh(grouped_data['state'], grouped_data[" Total Valid Votes"])
# Out:
# <BarContainer object of 37 artists>

# %%
#Shows number of won per candidate
grouped_data["Winner of states"].value_counts()
# Out:
# Winner of states
# Muhammadu Buhari    19
# Atiku Abubakar      18
# Name: count, dtype: int64
